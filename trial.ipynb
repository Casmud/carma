# %%
from src.db import create_db_and_tables
create_db_and_tables(debug=True)
# Out:
# 2025-01-12 15:53:04,114 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-01-12 15:53:04,115 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("fuel")
# 2025-01-12 15:53:04,116 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-12 15:53:04,117 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("partcategorylink")
# 2025-01-12 15:53:04,117 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-12 15:53:04,118 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("part")
# 2025-01-12 15:53:04,119 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-12 15:53:04,121 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("category")
# 2025-01-12 15:53:04,122 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-12 15:53:04,123 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("invoice")
# 2025-01-12 15:53:04,124 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-12 15:53:04,125 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("invoiceitem")
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NoForeignKeysError                        Traceback (most recent call last)
# File C:\pythonprojects\carma_local\.venv\Lib\site-packages\sqlalchemy\orm\relationships.py:2406, in JoinCondition._determine_joins(self)
#    2405 if self.secondaryjoin is None:
# -> 2406     self.secondaryjoin = join_condition(
#    2407         self.child_persist_selectable,
#    2408         self.secondary,
#    2409         a_subset=self.child_local_selectable,
#    2410         consider_as_foreign_keys=consider_as_foreign_keys,
#    2411     )
#    2412 if self.primaryjoin_initial is None:
#
# File C:\pythonprojects\carma_local\.venv\Lib\site-packages\sqlalchemy\sql\util.py:123, in join_condition(a, b, a_subset, consider_as_foreign_keys)
#     101 """Create a join condition between two tables or selectables.
#     102
#     103 e.g.::
#    (...)
#     121
#     122 """
# --> 123 return Join._join_condition(
#     124     a,
# ...
